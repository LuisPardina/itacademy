# %% [markdown]
# # Hello world!
# ## By Luis Pardina, student of Data Science @ IT Academy
# ### Created on March 23rd, 2022

# %% [markdown]
# This is my *first file* created with **Jupiter Notebook**
#
# See the beautiful use of ***cursive and bold text***

# %% [markdown]
# Find below an ordered list of my favorite sports:
# 1. Ski
# 2. Running
# 3. Rugby

# %% [markdown]
# And now an unordered list of my favorite music:
# - The Cure
# - Rimsky-Korsakov
# - Rosalia

# %%
#short code to print the content of a list
sports = ["Ski","Running","Rugby"]
for (i,v) in enumerate(sports):
    print("Luis'favorite sport number {0} is: {1}".format(i,v))
# Out:
# Luis'favorite sport number 0 is: Ski
# Luis'favorite sport number 1 is: Running
# Luis'favorite sport number 2 is: Rugby

# %%
from IPython.display import Image
Image("C:/Users/chufl/Pictures/Bandido Cucaracha.jpg")

# %% [markdown]
# The best place to learn (www.sololearn.com)
